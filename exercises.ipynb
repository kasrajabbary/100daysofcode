# %%
import os
import io
import csv
import pandas as pd
from urllib.request import urlopen , urlretrieve
from collections import Counter, namedtuple, OrderedDict
from itertools import groupby

# %%
from collections import defaultdict
midict = {}
firstname = {}
imdb_score = {}
movies = {}
years = {}
for lin in csv.DictReader(open("mvx.csv")):
    if lin['director_name'] != "":
            firstname[lin['director_name']] = firstname.get(lin['director_name'], 0) + 1
    if lin['imdb_score'] != '':
            imdb_score[lin['imdb_score']] = imdb_score.get(lin['imdb_score'], 0) + 1
    if lin['movie_title'] != '':
            movies[lin['movie_title']] = movies.get(lin['movie_title'], 0) + 1
    if lin['title_year'] != '' :
            years[lin['title_year']] = years.get(lin['title_year'], 0) + 1
            

count = 0    
for l in lin['director_name']:
    count = 0
    for i in l:
        count += 1
    
            
#     #if(lin['title_year'] != ''  and  int(lin['title_year'])>= 1960):
#     #        midict.append(lin['title_year'])
#     if Counter(lin['imdb_score'].most_common(5)):
#         midict.append(lin['director_name'])
#      #           for i, val in enumerate(row):
#       #              count_number[i]['director_name'] += 1
# #         for director in lin['director_name']:
            
# #             midict.append(lin['director_name'].split('0'))
# #             midict.append(lin['title_year'])

# %%
text = """this is whatever ok"""
# Out:
# 'Doug Walker'

# %%
count = 0    
for l in lin['director_name']:
    count = 0
    for i in l:
        count += 1
# Out:
# {}

# %%
lin['movie_title'].replace("\xa0", "")
# Out:
# 'Star Wars: Episode VII - The Force Awakens            '

# %%
firstname = {}
imdb_score = {}
movies = {}

with open('mvx.csv') as csv_file:
    reader = csv.DictReader(csv_file)
    for lin in reader:
        if lin['director_name'] != "":
            firstname[lin['director_name']] = firstname.get(lin['director_name'], 0) + 1
        if lin['imdb_score'] != '':
            imdb_score[lin['imdb_score']] = imdb_score.get(lin['imdb_score'], 0) + 1
        if lin['movie_title'] != '':
            movies[lin['movie_title']] = movies.get(lin['movie_title'], 0) + 1

# %%
OrderedDict(firstname)
# Out:
# OrderedDict([('James Cameron', 7),
#              ('Gore Verbinski', 7),
#              ('Sam Mendes', 8),
#              ('Christopher Nolan', 8),
#              ('Doug Walker', 3),
#              ('Andrew Stanton', 3),
#              ('Sam Raimi', 13),
#              ('Nathan Greno', 1),
#              ('Joss Whedon', 4),
#              ('David Yates', 4),
#              ('Zack Snyder', 8),
#              ('Bryan Singer', 8),
#              ('Marc Forster', 8),
#              ('Andrew Adamson', 5),
#              ('Rob Marshall', 5),
#              ('Barry Sonnenfeld', 7),
#              ('Peter Jackson', 12),
#              ('Marc Webb', 3),
#              ('Ridley Scott', 17),
#              ('Chris Weitz', 5),
#              ('Anthony Russo', 4),
#              ('Peter Berg', 6),
#              ('Colin Trevorrow', 2),
#              ('Shane Black', 2),
#              ('Tim Burton', 16),
#              ('Brett Ratner', 10),
#              ('Dan Scanlon', 1),
# ...

# %%
sentence = "The quick brown fox jumped over the lazy dog."
characters = {}

for character in sentence:
    characters[character] = characters.get(character, 0) + 1 

print(characters)
# Out:
# {'T': 1, 'h': 2, 'e': 4, ' ': 8, 'q': 1, 'u': 2, 'i': 1, 'c': 1, 'k': 1, 'b': 1, 'r': 2, 'o': 4, 'w': 1, 'n': 1, 'f': 1, 'x': 1, 'j': 1, 'm': 1, 'p': 1, 'd': 2, 'v': 1, 't': 1, 'l': 1, 'a': 1, 'z': 1, 'y': 1, 'g': 1, '.': 1}

# %%
for lin in csv.DictReader(open("mvx.csv")):
    for k in lin:
        if lin[k] != 'NaN':
            print(lin)
            
            
            director = lin['director_name']
            movie = lin['movie_title']
            year = int(lin['title_year'])
            score = float(lin['imdb_score'])
# Out:
# OrderedDict([('color', 'Color'), ('director_name', 'James Cameron'), ('num_critic_for_reviews', '723'), ('duration', '178'), ('director_facebook_likes', '0'), ('actor_3_facebook_likes', '855'), ('actor_2_name', 'Joel David Moore'), ('actor_1_facebook_likes', '1000'), ('gross', '760505847'), ('genres', 'Action|Adventure|Fantasy|Sci-Fi'), ('actor_1_name', 'CCH Pounder'), ('movie_title', 'Avatar\xa0'), ('num_voted_users', '886204'), ('cast_total_facebook_likes', '4834'), ('actor_3_name', 'Wes Studi'), ('facenumber_in_poster', '0'), ('plot_keywords', 'avatar|future|marine|native|paraplegic'), ('movie_imdb_link', 'http://www.imdb.com/title/tt0499549/?ref_=fn_tt_tt_1'), ('num_user_for_reviews', '3054'), ('language', 'English'), ('country', 'USA'), ('content_rating', 'PG-13'), ('budget', '237000000'), ('title_year', '2009'), ('actor_2_facebook_likes', '936'), ('imdb_score', '7.9'), ('aspect_ratio', '1.78'), ('movie_facebook_likes', '33000')])
# ...

# %%
cars = {
    'Ford': ['Falcon', 'Focus', 'Festiva', 'Fairlane'],
    'Holden': ['Commodore', 'Captiva', 'Barina', 'Trailblazer'],
    'Nissan': ['Maxima', 'Pulsar', '350Z', 'Navara'],
    'Honda': ['Civic', 'Accord', 'Odyssey', 'Jazz'],
    'Jeep': ['Grand Cherokee', 'Cherokee', 'Trailhawk', 'Trackhawk']
}

# %%
jeeps
# Out:
# ['Grand Cherokee', 'Cherokee', 'Trailhawk', 'Trackhawk']

# %%
player = { 'firstName': 'Jabari', 'lastName': 'Parker', 'jersey': '2', 'heightMeters': '2.03', 'nbaDebutYear': '2014' }

# %%
player
# Out:
# {'firstName': 'Jabari',
#  'lastName': 'Parker',
#  'jersey': '2',
#  'heightMeters': '2.03',
#  'nbaDebutYear': '2014'}

# %%
player['firstName'] = 'Parker'
player['lastName'] = 'jabari'

# %%
player.get('heightMeters', 0) +1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-620-367713890477> in <module>
# ----> 1 player.get('heightMeters', 0) +1
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = []
for i in cars.values():
        x.append(i[0].split())
        x.append(i[0][:3].split())

# %%
c = Counter(cars).most_common(5)

# %%
lest = []
for k,v in cars.items():
    lest.append(cars[k][0])

# %%
tsel = sorted(lest)

# %%
tsel
# Out:
# ['Civic', 'Commodore', 'Falcon', 'Grand Cherokee', 'Maxima']

# %%
lest
# Out:
# ['Civic', 'Commodore', 'Falcon', 'Grand Cherokee', 'Maxima']

# %%
for i in tsel:
    for j in lest:
        if i == j:
            print(i, j)
# Out:
# Civic Civic
# Commodore Commodore
# Falcon Falcon
# Grand Cherokee Grand Cherokee
# Maxima Maxima

# %%
zeep = [i[0] for i in cars.values()]

# %%
sorted(zeep)
# Out:
# ['Civic', 'Commodore', 'Falcon', 'Grand Cherokee', 'Maxima']

# %%
w = dict()
items = {'house': 'haus', 'cat':"", 'red':'rot'}

# %%
w = dict(items)

# %%
w
# Out:
# {'house': 'haus', 'cat': '', 'red': 'rot'}

# %%
for i,j in w.items():

    print(i,j)
# Out:
# house haus
# cat
# red rot

# %%
there = []
for i,j in w.items():
    there.append(i)
    there.append(j)

# %%
there
# Out:
# ['house', 'haus', 'cat', '', 'red', 'rot']

# %%
there[0]
# Out:
# 'house'

# %%
NAMES = ['arnold schwarzenegger', 'alec baldwin', 'bob belderbos',
         'julian sequeira', 'sandra bullock', 'keanu reeves',
         'julbob pybites', 'bob belderbos', 'julian sequeira',
         'al pacino', 'brad pitt', 'matt damon', 'brad pitt']

# %%
[name.title() for name in NAMES]
# Out:
# ['Arnold Schwarzenegger',
#  'Alec Baldwin',
#  'Bob Belderbos',
#  'Julian Sequeira',
#  'Sandra Bullock',
#  'Keanu Reeves',
#  'Julbob Pybites',
#  'Bob Belderbos',
#  'Julian Sequeira',
#  'Al Pacino',
#  'Brad Pitt',
#  'Matt Damon',
#  'Brad Pitt']

# %%
dictionary = {i for i in NAMES}

# %%
dictionary
# Out:
# {'al pacino',
#  'alec baldwin',
#  'arnold schwarzenegger',
#  'bob belderbos',
#  'brad pitt',
#  'julbob pybites',
#  'julian sequeira',
#  'keanu reeves',
#  'matt damon',
#  'sandra bullock'}

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-677-33761def2ac7> in <module>
# ----> 1 for k,v in dictionary:
#       2     print(k)
#
# ValueError: too many values to unpack (expected 2)
